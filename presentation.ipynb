# %%
from documents.acordao import Acordao
from documents.resolucao import Resolucao
from rich import print_json

acordao = Acordao()
resolucao = Resolucao()
# %load_ext rich
# Out:
# 2025-03-21 19:00:36.907 | DEBUG    | documents.acordao:__init__:24 - Inicializando Resolucao
# 2025-03-21 19:00:36.908 | WARNING  | documents.acordao:__init__:27 - Nenhum diario disponibilizado, usando o dia de hoje!
# 2025-03-21 19:00:36.909 | INFO     | documents.diario:_diario_existe:255 - Buscando URL: https://tcm.ioepa.com.br/busca/default.aspx?dts=21/3/2025
# 2025-03-21 19:00:37.034 | INFO     | documents.diario:_diario_existe:288 - URL do PDF encontrada: https://tcm.ioepa.com.br/diarios/2025/2025.03.21.DOE.pdf
# 2025-03-21 19:00:37.035 | INFO     | documents.diario:__init__:150 - Diário encontrado para 21/3/2025
# 2025-03-21 19:00:37.037 | INFO     | documents.diario:_pdf_disponivel:336 - PDF encontrado e não vazio: /run/media/joaompessoa/Extreme Pro/Projeto Diario/diario_oficial/diarios/2025/03/2025.03.21.DOE.pdf
# 2025-03-21 19:00:37.038 | INFO     | documents.diario:__init__:184 - PDF válido encontrado: 2025.03.21.DOE.pdf
# ...

# %%
resolucao.documentos
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     DocumentoDiarioOficial(
#         categoria='resolucao',
#         sessao='21 de março de 2025',
#         numero='17.182',
#         publicacao='21/3/2025',
#         processo='Processo nº 019001.2018.1.000 (019001.2018.2.000)',
#         município='Bujaru',
#         gestora='Prefeitura Municipal',
#         assunto='Contas Anuais do Chefe do Poder Executivo Municipal',
#         interessado='Jorge Sato (CPF: [REDIGIDO])',
#         contador='Carlos Vittor de Andrade Monteiro',
#         instrução='6ª Controladoria',
#         contas='Marcelo Fonseca Barros',
#         relator='Conselheiro Lúcio Vale',
#         exercício='2018',
# ...
