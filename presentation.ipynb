# %%
from documents.diario import DiarioOficial
from documents.acordao import Acordao
from rich import print
from util.validate_keys import validate_document_keys
# %load_ext rich

# %%
diario = DiarioOficial(dia=19)

# %%
print(diario.texto_preview)
# Out:
# Quarta-feira, 19 de março de 2025 DOE TCMPA Nº 1.912 2    Consulta via leitora de QR Code/ Este Diár...

# %%
acordao = Acordao(diario=DiarioOficial(dia=19, mes=3, ano=2025))
# Out:
# 2025-03-20 21:03:14.782 | INFO     | documents.diario:_diario_existe:230 - Buscando URL: https://tcm.ioepa.com.br/busca/default.aspx?dts=19/3/2025
# 2025-03-20 21:03:15.407 | INFO     | documents.diario:_diario_existe:261 - URL do PDF encontrada: https://tcm.ioepa.com.br/diarios/2025/2025.03.19.DOE.pdf
# 2025-03-20 21:03:15.409 | DEBUG    | documents.diario:__init__:144 - Parametros da classe DiarioOficial: {'dia': 20, 'mes': 3, 'ano': 2025, 'publicacao': '19/3/2025', 'numero_diario': '', 'ioepa_endpoint': 'https://tcm.ioepa.com.br/busca/default.aspx?dts=19/3/2025', 'texto_original': '', 'diario_valido': True, 'download_dir': PosixPath('/run/media/joaompessoa/Extreme Pro/Projeto Diario/diario_oficial/diarios'), 'pdf_file': '2025.03.19.DOE.pdf', 'local_path': '', 'internet_path': 'https://tcm.ioepa.com.br/diarios/2025/2025.03.19.DOE.pdf', 'data_diario': {'dia': 19, 'mes': 3, 'ano': 2025}, 'limpar_texto': True}
# ...

# %%
sections = acordao.get_sections(self=acordao)

# %%
sections
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
# ...

# %%
print(acordao._get_keys(text=sections[0]))
# Out:
# 2025-03-20 21:03:35.723 | INFO     | documents.document:_get_keys:127 - Extraindo chaves do texto
# 2025-03-20 21:03:35.723 | DEBUG    | documents.document:_get_keys:129 - Chaves encontradas: ['MUNICÍPIO', 'ÓRGÃO', 'EXERCÍCIO', 'ASSUNTO', 'ORDENADORES', 'CPF', 'CPF', 'CPF', 'CONTADORA', 'MPC', 'RELATOR', 'EMENTA', 'DECISÃO', 'Endereço']
# ['MUNICÍPIO', 'ÓRGÃO', 'EXERCÍCIO', 'ASSUNTO', 'ORDENADORES', 'CONTADORA', 'MPC', 'RELATOR', 'EMENTA', 'DECISÃO']

# %%
acordao.documentos
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     DocumentoDiarioOficial(
#         categoria='acordao',
#         sessao='19 de março de 2025',
#         numero='46.771',
#         publicacao='19/3/2025',
# ...
